# %%
import pandas as pd

# %%
sancor_clean = pd.read_excel('../data_clean/sancor_clean.xlsx')
zurich_clean = pd.read_excel('../data_clean/zurich_clean.xlsx')

# %%
tabla_maestra = pd.concat([sancor_clean, zurich_clean], ignore_index=True)

# %%
# Concatenar las tablas
tabla_maestra = pd.concat([sancor_clean, zurich_clean], ignore_index=True)

# Eliminar la columna 'Unnamed: 0' si está presente
if 'Unnamed: 0' in tabla_maestra.columns:
    tabla_maestra = tabla_maestra.drop('Unnamed: 0', axis=1)

# %%
tabla_maestra.head(1)
# Out:
#    seguro fecha_reporte   producto numero_poliza      prima prc_comision  \
# 0  sancor    20/02/2025  monopatín      sp-48206  458022.14            5
#
#    monto_comision estado_pago   canal_venta              productor
# 0        22901.11   pendiente  joaquin diaz  luciana soria ramirez

# %%
tabla_maestra.to_excel('../output/tabla_maestra.xlsx', engine='openpyxl')
